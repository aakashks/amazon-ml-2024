# %%
import pandas as pd

df = pd.read_csv('student_resource 3/dataset/test.csv')
df
# Out:
#          index                                         image_link  group_id  \
# 0            0  https://m.media-amazon.com/images/I/110EibNycl...    156839
# 1            1  https://m.media-amazon.com/images/I/11TU2clswz...    792578
# 2            2  https://m.media-amazon.com/images/I/11TU2clswz...    792578
# 3            3  https://m.media-amazon.com/images/I/11TU2clswz...    792578
# 4            4  https://m.media-amazon.com/images/I/11gHj8dhhr...    792578
# ...        ...                                                ...       ...
# 131182  131283  https://m.media-amazon.com/images/I/A1rVsIzEtk...    721522
# 131183  131284  https://m.media-amazon.com/images/I/A1rdvZ5zDd...    603688
# 131184  131285  https://m.media-amazon.com/images/I/A1rdvZ5zDd...    603688
# 131185  131286  https://m.media-amazon.com/images/I/A1tnTUPyr7...    853009
# 131186  131287  https://m.media-amazon.com/images/I/A1tnTUPyr7...    853009
#
#                           entity_name
# 0                              height
# 1                               width
# 2                              height
# 3                               depth
# 4                               depth
# ...                               ...
# 131182  maximum_weight_recommendation
# 131183                    item_weight
# 131184  maximum_weight_recommendation
# 131185                    item_weight
# 131186  maximum_weight_recommendation
#
# [131187 rows x 4 columns]

# %%
# load all json files in the directory in one dictionary
import os
import json

all_jsons = []

dir = 'llama_output/4'

for file in os.listdir(dir):
    with open(f'{dir}/{file}') as f:
        all_jsons.extend(json.load(f))

# %%
len(all_jsons)
# Out:
# 20190

# %%
llm = pd.DataFrame(all_jsons)
llm
# Out:
#        index                                         image_link  entity_name  \
# 0      17651  https://m.media-amazon.com/images/I/41vWG7yOeF...        depth
# 1      17652  https://m.media-amazon.com/images/I/41vWrkYLvB...  item_volume
# 2      17667  https://m.media-amazon.com/images/I/41vcJJrlwu...        depth
# 3      17681  https://m.media-amazon.com/images/I/41vf60e0Ih...      voltage
# 4      17682  https://m.media-amazon.com/images/I/41vf60e0Ih...      wattage
# ...      ...                                                ...          ...
# 20185  88159  https://m.media-amazon.com/images/I/614PQu7Qx5...       height
# 20186  88163  https://m.media-amazon.com/images/I/614PZqYaf1...  item_volume
# 20187  88178  https://m.media-amazon.com/images/I/614QBVy4-G...        depth
# 20188  88196  https://m.media-amazon.com/images/I/614QeYCASS...  item_volume
# 20189  88197  https://m.media-amazon.com/images/I/614Qiaz8fE...        depth
#
#                                       measurement_result
# 0      There is no numerical value and unit for "dept...
# 1                     {\n  "item_volume": "2.5 FL OZ"\n}
# 2      There is no numerical value and unit for "dept...
# 3      The text does not mention "voltage". However, ...
# 4      There is no information about wattage in the g...
# ...                                                  ...
# 20185  The text does not contain any information abou...
# 20186                {\n  "item_volume": "12.5 FL OZ"\n}
# 20187  The text does not contain any information abou...
# 20188               {\n  "item_volume": "168.0 Fl Oz"\n}
# 20189                           {\n  "depth": "3.93 "\n}
#
# [20190 rows x 4 columns]

# %%
# merge but only add column vlm_output

merged_df = pd.merge(df, llm[['index', 'measurement_result']], on='index', how='right')

# %%
(merged_df['measurement_result'].isna()).mean()
# Out:
# 0.0

# %%
merged_df.rename(columns={'measurement_result': 'llm_output'}, inplace=True)
merged_df
# Out:
#        index                                         image_link  group_id  \
# 0      17651  https://m.media-amazon.com/images/I/41vWG7yOeF...    494658
# 1      17652  https://m.media-amazon.com/images/I/41vWrkYLvB...    369753
# 2      17667  https://m.media-amazon.com/images/I/41vcJJrlwu...    292475
# 3      17681  https://m.media-amazon.com/images/I/41vf60e0Ih...    957050
# 4      17682  https://m.media-amazon.com/images/I/41vf60e0Ih...    957050
# ...      ...                                                ...       ...
# 20185  88159  https://m.media-amazon.com/images/I/614PQu7Qx5...    801829
# 20186  88163  https://m.media-amazon.com/images/I/614PZqYaf1...    608041
# 20187  88178  https://m.media-amazon.com/images/I/614QBVy4-G...    648011
# 20188  88196  https://m.media-amazon.com/images/I/614QeYCASS...    941694
# 20189  88197  https://m.media-amazon.com/images/I/614Qiaz8fE...    776058
#
#        entity_name                                         llm_output
# 0            depth  There is no numerical value and unit for "dept...
# 1      item_volume                 {\n  "item_volume": "2.5 FL OZ"\n}
# 2            depth  There is no numerical value and unit for "dept...
# 3          voltage  The text does not mention "voltage". However, ...
# 4          wattage  There is no information about wattage in the g...
# ...            ...                                                ...
# 20185       height  The text does not contain any information abou...
# 20186  item_volume                {\n  "item_volume": "12.5 FL OZ"\n}
# 20187        depth  The text does not contain any information abou...
# 20188  item_volume               {\n  "item_volume": "168.0 Fl Oz"\n}
# 20189        depth                           {\n  "depth": "3.93 "\n}
#
# [20190 rows x 5 columns]

# %%
# save the csv file

merged_df.to_csv('extracted/cumulative_nans_outputs.csv', index=False)
